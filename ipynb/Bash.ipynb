# %% [markdown]
# ## Markdown test ##
# The LaTex equation are working
# $a_1^2$
#
# Let's chech, id the bash script is working.

# %%
#This is Bash script
for file in `ls`
do
    echo "I have a file $file"
done
# Out:
# I have a file 3.2.3.8
# I have a file Lab
# I have a file -
# I have a file Basic
# I have a file Linux
# I have a file Commands
# I have a file 3.2.4.5
# I have a file Lab
# I have a file -
# I have a file Writing
# I have a file Python
# I have a file Scripts
# I have a file Using
# I have a file Blockly
# I have a file 3.2.5.10
# I have a file Lab
# I have a file -
# I have a file Writing
# I have a file Python
# I have a file Scripts
# I have a file Using
# I have a file a
# I have a file Text
# I have a file Editor
# I have a file 3.2.5.11
# I have a file Lab
# I have a file -
# I have a file Blinking
# I have a file an
# I have a file LED
# I have a file using
# I have a file Raspberry
# I have a file Pi
# I have a file and
# I have a file PL-App
# I have a file 3.2.5.14
# I have a file Lab
# I have a file -
# I have a file Interacting
# I have a file with
# I have a file a
# I have a file physical
# I have a file world
# I have a file from
# I have a file Cisco
# ...
